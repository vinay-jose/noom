# %% [raw]
# ---
# description: noom is python library that defines Noom datatype - an alternative to
#   number type but with limited capabilities. This is developed as part of a learning
#   exercise in literate programmimg - using [nbdev](https://nbdev.fast.ai) and [fastcore](https://fastcore.fast.ai).
#   The goal here is to create a `noom` class whose objects are compatible with common
#   arithmetic (+, -, x, /, //) and comparison(=, < , >, <=, >=) operators.
# output-file: core.html
# title: Noom's source
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Noom)
# Out:
# ---
#
# [source](https://github.com/vinay-jose/noom/blob/main/noom/core.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### Noom
#
# >      Noom (val)
#
# *Noom is a number datatype alternative with limited capabilities.*

# %%
#| echo: false
#| output: asis
show_doc(Noom.__add__)
# Out:
# ---
#
# [source](https://github.com/vinay-jose/noom/blob/main/noom/core.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### Noom.__add__
#
# >      Noom.__add__ (oth)

# %%
#| echo: false
#| output: asis
show_doc(Noom.__sub__)
# Out:
# ---
#
# [source](https://github.com/vinay-jose/noom/blob/main/noom/core.py#L31){target="_blank" style="float:right; font-size:smaller"}
#
# ### Noom.__sub__
#
# >      Noom.__sub__ (oth)

# %%
#| echo: false
#| output: asis
show_doc(Noom.__mul__)
# Out:
# ---
#
# [source](https://github.com/vinay-jose/noom/blob/main/noom/core.py#L36){target="_blank" style="float:right; font-size:smaller"}
#
# ### Noom.__mul__
#
# >      Noom.__mul__ (oth)

# %%
#| echo: false
#| output: asis
show_doc(Noom.__truediv__)
# Out:
# ---
#
# [source](https://github.com/vinay-jose/noom/blob/main/noom/core.py#L41){target="_blank" style="float:right; font-size:smaller"}
#
# ### Noom.__truediv__
#
# >      Noom.__truediv__ (oth)

# %%
#| echo: false
#| output: asis
show_doc(Noom.__floordiv__)
# Out:
# ---
#
# [source](https://github.com/vinay-jose/noom/blob/main/noom/core.py#L46){target="_blank" style="float:right; font-size:smaller"}
#
# ### Noom.__floordiv__
#
# >      Noom.__floordiv__ (oth)

# %% [markdown]
# Now, we have defined the arithmetic operations for noom objects using Python's magic methods. Let's take a look at few examples:

# %%
a = Noom(5)
b = Noom(6)

# %%
a + b
# Out:
# 11

# %%
a - b
# Out:
# -1

# %%
a * b
# Out:
# 30

# %%
a / b
# Out:
# 0.8333333333333334

# %%
b // a
# Out:
# 1

# %%
#| echo: false
#| output: asis
show_doc(Noom.__eq__)
# Out:
# ---
#
# [source](https://github.com/vinay-jose/noom/blob/main/noom/core.py#L51){target="_blank" style="float:right; font-size:smaller"}
#
# ### Noom.__eq__
#
# >      Noom.__eq__ (oth)
#
# *Return self==value.*

# %% [markdown]
# Let's define a few nooms and look at examples...

# %%
p = Noom(5)
q = Noom(5)
r = Noom(6)

# %% [markdown]
# Here are a couple of example to check equality of noom objects:

# %%
p == q, p != q
# Out:
# (True, False)

# %%
p == r, p != r
# Out:
# (False, True)

# %% [markdown]
# Equality check can be done for Noom objects only after `__eq__` is defined. So now, we can add tests for the arithmetic operators as weel.

# %%
test_eq(a + b, Noom(11))

# %% [markdown]
# We need not define `__ne__` , it is auto inferred by python once `__eq__` is defined. This is valid for other comparison operators too.

# %%
test_ne(a + b, Noom(12))

# %%
#| echo: false
#| output: asis
show_doc(Noom.__lt__)
# Out:
# ---
#
# [source](https://github.com/vinay-jose/noom/blob/main/noom/core.py#L56){target="_blank" style="float:right; font-size:smaller"}
#
# ### Noom.__lt__
#
# >      Noom.__lt__ (oth)
#
# *Return self<value.*

# %% [markdown]
# Examples:

# %%
p < q, p > q
# Out:
# (False, False)

# %%
p < r, p > r
# Out:
# (True, False)

# %%
#| echo: false
#| output: asis
show_doc(Noom.__le__)
# Out:
# ---
#
# [source](https://github.com/vinay-jose/noom/blob/main/noom/core.py#L61){target="_blank" style="float:right; font-size:smaller"}
#
# ### Noom.__le__
#
# >      Noom.__le__ (oth)
#
# *Return self<=value.*

# %% [markdown]
# Examples:

# %%
p <= q, p >= q
# Out:
# (True, True)

# %%
p <= r, p >= r
# Out:
# (True, False)
