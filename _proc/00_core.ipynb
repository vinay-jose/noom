# %% [raw]
# ---
# description: Noom class definition - arithmetic and comparison operations
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Noom)
# Out:
# ---
#
# [source](https://github.com/vinay-jose/noom/blob/main/noom/core.py#L9){target="_blank" style="float:right; font-size:smaller"}
#
# ### Noom
#
# >      Noom (val)
#
# *Initialize self.  See help(type(self)) for accurate signature.*

# %%
a = Noom(5)
b = Noom(6)

# %%
a + b
# Out:
# 11

# %%
a - b
# Out:
# -1

# %%
a * b
# Out:
# 30

# %%
a / b
# Out:
# 0.8333333333333334

# %%
b // a
# Out:
# 1

# %%
#| echo: false
#| output: asis
show_doc(Noom.__eq__)
# Out:
# ---
#
# [source](https://github.com/vinay-jose/noom/blob/main/noom/core.py#L40){target="_blank" style="float:right; font-size:smaller"}
#
# ### Noom.__eq__
#
# >      Noom.__eq__ (oth)
#
# *Return self==value.*

# %%
test_eq(a + b, Noom(11))

# %%
test_eq(a - b, Noom(-1))
test_eq(a * b, Noom(30))
test_eq(a / b, Noom(5/6))
test_eq(a // b, Noom(0))

# %%
#| echo: false
#| output: asis
show_doc(Noom.__lt__)
# Out:
# ---
#
# [source](https://github.com/vinay-jose/noom/blob/main/noom/core.py#L45){target="_blank" style="float:right; font-size:smaller"}
#
# ### Noom.__lt__
#
# >      Noom.__lt__ (oth)
#
# *Return self<value.*

# %%
p = Noom(5)
q = Noom(5)

# %%
p < q, p > q, p == q, p != q
# Out:
# (False, False, True, False)

# %%
#| echo: false
#| output: asis
show_doc(Noom.__le__)
# Out:
# ---
#
# [source](https://github.com/vinay-jose/noom/blob/main/noom/core.py#L50){target="_blank" style="float:right; font-size:smaller"}
#
# ### Noom.__le__
#
# >      Noom.__le__ (oth)
#
# *Return self<=value.*

# %%
p <= q, p >= q
# Out:
# (True, True)
