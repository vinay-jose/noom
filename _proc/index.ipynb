# %% [raw]
# ---
# description: A number class in python created using nbdev for learning.
# output-file: index.html
# title: Noom
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install noom in Development mode

# %% [markdown]
# ```sh
# # make sure noom package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to noom
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/vinay-jose/noom.git
# ```
#
# or from [pypi][pypi]
#
# ```sh
# $ pip install noom
# ```
#
#
# [repo]: https://github.com/vinay-jose/noom
# [docs]: https://vinayjose.com/noom/
# [pypi]: https://pypi.org/project/noom/
# [conda]: https://anaconda.org/vinay-jose/noom

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/vinay-jose/noom
# [docs]: https://vinay-jose.github.io/noom/
# [pypi]: https://pypi.org/project/noom/
# [conda]: https://anaconda.org/vinay-jose/noom

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
a = Noom(2)
b = Noom(4)

# %%
a + b
# Out:
# 6

# %%
a - b
# Out:
# -2

# %%
a * b
# Out:
# 8

# %%
a / b
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 a / b
#
# File ~\Documents\nbdev\noom\noom\core.py:29, in Noom.__truediv__(self, oth)
#      28 def __truediv__(self, oth):
# ---> 29     return Noom(self.val / oth.val)
#
# File ~\Documents\nbdev\noom\noom\core.py:11, in Noom.__init__(self, val)
#      10 def __init__(self, val):
# ---> 11     assert isinstance(val, int)
#      12     self.val = val
#
# AssertionError:

# %%
a // b
# Out:
# 0

# %%
a == b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a >= b
# Out:
# False
